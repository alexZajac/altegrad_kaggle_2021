# %%
# !pip install gdown
# !pip install ipython-autotime
# !pip install networkx
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (3.6.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.41.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (3.0.4)
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.7/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (53.0.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.5)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx) (4.4.2)

# %%
# %load_ext autotime
# Out:
# time: 188 µs (started: 2021-02-27 10:36:18 +00:00)

# %%
# !gdown "https://drive.google.com/uc?id=1Qbi954Bwx-PplM8F_7TrB_blcqcB-bF2"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Qbi954Bwx-PplM8F_7TrB_blcqcB-bF2
# To: /content/train.csv
# 100% 305k/305k [00:00<00:00, 83.6MB/s]
# time: 2.53 s (started: 2021-02-27 10:36:18 +00:00)

# %%
# !gdown "https://drive.google.com/uc?id=1hWycEy8rQ8e_krGyUhqGQiMBxZtD9SWy"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hWycEy8rQ8e_krGyUhqGQiMBxZtD9SWy
# To: /content/test.csv
# 2.47MB [00:00, 79.1MB/s]
# time: 920 ms (started: 2021-02-27 10:36:21 +00:00)

# %%
# !gdown "https://drive.google.com/uc?id=1IATZNB9SCDWkPhU1okCKwf_NMFSC_LSn"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IATZNB9SCDWkPhU1okCKwf_NMFSC_LSn
# To: /content/collaboration_network_weighted.edgelist
# 113MB [00:00, 147MB/s]
# time: 2.04 s (started: 2021-02-27 10:36:22 +00:00)

# %%
import pandas as pd
import numpy as np
import networkx as nx
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from pathlib import Path

# read training data
df_train = pd.read_csv('train.csv', dtype={'authorID': np.int64, 'h_index': np.float32})
n_train = df_train.shape[0]

# read test data
df_test = pd.read_csv('test.csv', dtype={'authorID': np.int64})
n_test = df_test.shape[0]

# load the graph
G = nx.read_edgelist('collaboration_network_weighted.edgelist',
                     delimiter=' ', nodetype=int)
n_nodes = G.number_of_nodes()
n_edges = G.number_of_edges()
print('Number of nodes:', n_nodes)
print('Number of edges:', n_edges)
# Out:
# Number of nodes: 231239
# Number of edges: 2982240
# time: 50.4 s (started: 2021-02-27 10:36:24 +00:00)

# %%
# remove 1-links
removed_edges = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] == 1.0]
# Out:
# time: 3.32 s (started: 2021-02-27 10:37:14 +00:00)

# %%
G.remove_edges_from(removed_edges)
G.number_of_edges()
# Out:
# 1284664
# time: 2.67 s (started: 2021-02-27 10:37:18 +00:00)

# %%
from random import sample

N = 100
random_nodes = G.subgraph(sample(list(G.nodes()), N))
# Out:
# time: 18.4 ms (started: 2021-02-27 10:37:20 +00:00)

# %%
import networkx as nx

methods = []
for i in dir(nx.algorithms):
    if type(getattr(nx.algorithms, i)).__name__ == "function":
        methods.append(getattr(nx.algorithms, i))
len(methods)
# Out:
# 390
# time: 7.97 ms (started: 2021-02-27 10:37:20 +00:00)

# %%
def _produce_name(method_address):
    return str(method_address).split(" ")[1]

benchmark = {}
# Out:
# time: 2.64 ms (started: 2021-02-27 10:37:20 +00:00)

# %%
from tqdm.notebook import tqdm
from time import time
import numbers

allowed_methods = []

for method in tqdm(methods):
    method_repr = _produce_name(method)
    print(method_repr, end="")
    start = time()
    try:
        res = method(random_nodes)
        if type(res) == dict and list(res.keys())[0] in random_nodes.nodes() and isinstance(list(res.values())[0], numbers.Number):
            benchmark[method] = time()-start
            print(": Added")
        else:
            print(": Not added")
    except Exception as e:
        print(": Not added")
        print(str(e) + "\n")
        if method_repr in allowed_methods:
            benchmark[method] = time()-start
        pass
# Out:
# HBox(children=(FloatProgress(value=0.0, max=390.0), HTML(value='')))
# adamic_adar_index: Not added
# all_node_cuts: Not added
# all_pairs_bellman_ford_path: Not added
# all_pairs_bellman_ford_path_length: Not added
# all_pairs_dijkstra: Not added
# all_pairs_dijkstra_path: Not added
# all_pairs_dijkstra_path_length: Not added
# all_pairs_lowest_common_ancestor: Not added
# not implemented for undirected type
#
# all_pairs_node_connectivity: Not added
# all_pairs_shortest_path: Not added
# all_pairs_shortest_path_length: Not added
# all_shortest_paths: Not added
# all_shortest_paths() missing 2 required positional arguments: 'source' and 'target'
#
# all_simple_edge_paths: Not added
# all_simple_edge_paths() missing 2 required positional arguments: 'source' and 'target'
#
# all_simple_paths: Not added
# all_simple_paths() missing 2 required positional arguments: 'source' and 'target'
#
# all_topological_sorts: Not added
# not implemented for undirected type
#
# all_triads: Not added
# not implemented for undirected type
#
# all_triplets: Not added
# not implemented for undirected type
#
# ancestors: Not added
# ancestors() missing 1 required positional argument: 'source'
#
# antichains: Not added
# not implemented for undirected type
#
# approximate_current_flow_betweenness_centrality: Not added
# Graph not connected.
#
# articulation_points: Not added
# astar_path: Not added
# astar_path() missing 2 required positional arguments: 'source' and 'target'
#
# astar_path_length: Not added
# astar_path_length() missing 2 required positional arguments: 'source' and 'target'
#
# attracting_components: Not added
# not implemented for undirected type
#
# attribute_assortativity_coefficient: Not added
# attribute_assortativity_coefficient() missing 1 required positional argument: 'attribute'
#
# attribute_mixing_dict: Not added
# attribute_mixing_dict() missing 1 required positional argument: 'attribute'
#
# attribute_mixing_matrix: Not added
# attribute_mixing_matrix() missing 1 required positional argument: 'attribute'
#
# authority_matrix: Not added
# average_clustering: Not added
# average_degree_connectivity: Not added
# average_neighbor_degree: Added
# average_node_connectivity: Not added
# average_shortest_path_length: Not added
# Graph is not connected.
#
# barycenter: Not added
# Input graph  is disconnected, so every induced subgraph has infinite barycentricity.
#
# bellman_ford_path: Not added
# bellman_ford_path() missing 2 required positional arguments: 'source' and 'target'
#
# bellman_ford_path_length: Not added
# bellman_ford_path_length() missing 2 required positional arguments: 'source' and 'target'
#
# bellman_ford_predecessor_and_distance: Not added
# bellman_ford_predecessor_and_distance() missing 1 required positional argument: 'source'
#
# betweenness_centrality: Added
# betweenness_centrality_source: Added
# betweenness_centrality_subset: Not added
# betweenness_centrality_subset() missing 2 required positional arguments: 'sources' and 'targets'
#
# bfs_beam_edges: Not added
# bfs_beam_edges() missing 2 required positional arguments: 'source' and 'value'
#
# bfs_edges: Not added
# bfs_edges() missing 1 required positional argument: 'source'
#
# bfs_predecessors: Not added
# bfs_predecessors() missing 1 required positional argument: 'source'
#
# bfs_successors: Not added
# bfs_successors() missing 1 required positional argument: 'source'
#
# bfs_tree: Not added
# bfs_tree() missing 1 required positional argument: 'source'
#
# biconnected_component_edges: Not added
# biconnected_components: Not added
# bidirectional_dijkstra: Not added
# bidirectional_dijkstra() missing 2 required positional arguments: 'source' and 'target'
#
# bidirectional_shortest_path: Not added
# bidirectional_shortest_path() missing 2 required positional arguments: 'source' and 'target'
#
# boundary_expansion: Not added
# boundary_expansion() missing 1 required positional argument: 'S'
#
# bridges: Not added
# capacity_scaling: Not added
# not implemented for undirected type
#
# cartesian_product: Not added
# cartesian_product() missing 1 required positional argument: 'H'
#
# center: Not added
# Found infinite path length because the graph is not connected
#
# chain_decomposition: Not added
# check_planarity: Not added
# chordal_graph_cliques: Not added
# chordal_graph_treewidth: Not added
# cliques_containing_node: Not added
# closeness_centrality: Added
# closeness_vitality: Added
# clustering: Added
# cn_soundarajan_hopcroft: Not added
# combinatorial_embedding_to_pos: Not added
# common_neighbor_centrality: Not added
# communicability: Not added
# communicability_betweenness_centrality: Added
# communicability_exp
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/centrality/subgraph_alg.py:274: RuntimeWarning: invalid value encountered in true_divide
#   B = (expA - scipy.linalg.expm(A)) / expA
# : Not added
# complement: Not added
# complete_bipartite_graph: Not added
# complete_bipartite_graph() missing 1 required positional argument: 'n2'
#
# complete_to_chordal_graph: Not added
# compose: Not added
# compose() missing 1 required positional argument: 'H'
#
# compose_all: Not added
# 'int' object has no attribute 'is_multigraph'
#
# condensation: Not added
# not implemented for undirected type
#
# conductance: Not added
# conductance() missing 1 required positional argument: 'S'
#
# connected_components: Not added
# connected_double_edge_swap: Not added
# Graph not connected
#
# constraint: Added
# contracted_edge: Not added
# contracted_edge() missing 1 required positional argument: 'edge'
#
# contracted_nodes: Not added
# contracted_nodes() missing 2 required positional arguments: 'u' and 'v'
#
# core_number: Added
# cost_of_flow: Not added
# cost_of_flow() missing 1 required positional argument: 'flowDict'
#
# could_be_isomorphic: Not added
# could_be_isomorphic() missing 1 required positional argument: 'G2'
#
# current_flow_betweenness_centrality: Not added
# Graph not connected.
#
# current_flow_betweenness_centrality_subset: Not added
# current_flow_betweenness_centrality_subset() missing 2 required positional arguments: 'sources' and 'targets'
#
# current_flow_closeness_centrality: Not added
# Graph not connected.
#
# cut_size: Not added
# cut_size() missing 1 required positional argument: 'S'
#
# cycle_basis: Not added
# d_separated: Not added
# d_separated() missing 3 required positional arguments: 'x', 'y', and 'z'
#
# dag_longest_path: Not added
# not implemented for undirected type
#
# dag_longest_path_length: Not added
# not implemented for undirected type
#
# dag_to_branching: Not added
# not implemented for undirected type
#
# degree_assortativity_coefficient: Not added
# max() arg is an empty sequence
#
# degree_centrality: Added
# degree_mixing_dict: Not added
# list index out of range
#
# degree_mixing_matrix: Not added
# max() arg is an empty sequence
#
# degree_pearson_correlation_coefficient: Not added
# not enough values to unpack (expected 2, got 0)
#
# descendants: Not added
# descendants() missing 1 required positional argument: 'source'
#
# descendants_at_distance: Not added
# descendants_at_distance() missing 2 required positional arguments: 'source' and 'distance'
#
# dfs_edges: Not added
# dfs_labeled_edges: Not added
# dfs_postorder_nodes: Not added
# dfs_predecessors: Not added
# list index out of range
#
# dfs_preorder_nodes: Not added
# dfs_successors: Not added
# list index out of range
#
# dfs_tree: Not added
# diameter: Not added
# Found infinite path length because the graph is not connected
#
# difference: Not added
# difference() missing 1 required positional argument: 'H'
#
# dijkstra_path: Not added
# dijkstra_path() missing 2 required positional arguments: 'source' and 'target'
#
# dijkstra_path_length: Not added
# dijkstra_path_length() missing 2 required positional arguments: 'source' and 'target'
#
# dijkstra_predecessor_and_distance: Not added
# dijkstra_predecessor_and_distance() missing 1 required positional argument: 'source'
#
# disjoint_union: Not added
# disjoint_union() missing 1 required positional argument: 'H'
#
# disjoint_union_all: Not added
# 'int' object has no attribute 'number_of_nodes'
#
# dispersion: Not added
# dominance_frontiers: Not added
# dominance_frontiers() missing 1 required positional argument: 'start'
#
# dominating_set: Not added
# double_edge_swap: Not added
# float division by zero
#
# eccentricity: Not added
# Found infinite path length because the graph is not connected
#
# edge_betweenness: Not added
# list index out of range
#
# edge_betweenness_centrality: Not added
# list index out of range
#
# edge_betweenness_centrality_subset: Not added
# edge_betweenness_centrality_subset() missing 2 required positional arguments: 'sources' and 'targets'
#
# edge_bfs: Not added
# edge_boundary: Not added
# edge_boundary() missing 1 required positional argument: 'nbunch1'
#
# edge_connectivity: Not added
# edge_current_flow_betweenness_centrality: Not added
# Graph not connected.
#
# edge_current_flow_betweenness_centrality_subset: Not added
# edge_current_flow_betweenness_centrality_subset() missing 2 required positional arguments: 'sources' and 'targets'
#
# edge_dfs: Not added
# edge_disjoint_paths: Not added
# edge_disjoint_paths() missing 2 required positional arguments: 's' and 't'
#
# edge_expansion: Not added
# edge_expansion() missing 1 required positional argument: 'S'
#
# edge_load_centrality: Not added
# list index out of range
#
# effective_size: Added
# efficiency: Not added
# efficiency() missing 2 required positional arguments: 'u' and 'v'
#
# eigenvector_centrality: Added
# eigenvector_centrality_numpy: Added
# enumerate_all_cliques: Not added
# equitable_color: Not added
# equitable_color() missing 1 required positional argument: 'num_colors'
#
# estrada_index: Not added
# eulerian_circuit: Not added
# eulerian_path: Not added
# eulerize: Not added
# G is not connected
#
# extrema_bounding: Not added
# Cannot compute metric because graph is not connected.
#
# fast_could_be_isomorphic: Not added
# fast_could_be_isomorphic() missing 1 required positional argument: 'G2'
#
# faster_could_be_isomorphic: Not added
# faster_could_be_isomorphic() missing 1 required positional argument: 'G2'
#
# find_asteroidal_triple: Not added
# find_cliques: Not added
# find_cliques_recursive: Not added
# core_number: Added
# find_cycle: Not added
# No cycle found.
#
# find_induced_nodes: Not added
# find_induced_nodes() missing 2 required positional arguments: 's' and 't'
#
# flow_hierarchy: Not added
# G must be a digraph in flow_hierarchy
#
# floyd_warshall: Not added
# floyd_warshall_numpy: Not added
# floyd_warshall_predecessor_and_distance: Not added
# from_nested_tuple: Not added
# object of type 'int' has no len()
#
# from_prufer_sequence: Not added
# too many values to unpack (expected 2)
#
# full_join: Not added
# full_join() missing 1 required positional argument: 'H'
#
# generalized_degree: Not added
# global_efficiency: Not added
# global_parameters: Not added
# global_parameters() missing 1 required positional argument: 'c'
#
# global_reaching_centrality: Not added
# Size of G must be positive
#
# goldberg_radzik: Not added
# goldberg_radzik() missing 1 required positional argument: 'source'
#
# gomory_hu_tree: Not added
# google_matrix: Not added
# graph_clique_number: Not added
# graph_edit_distance: Not added
# graph_edit_distance() missing 1 required positional argument: 'G2'
#
# graph_number_of_cliques: Not added
# greedy_color: Added
# group_betweenness_centrality: Not added
# group_betweenness_centrality() missing 1 required positional argument: 'C'
#
# group_closeness_centrality: Not added
# group_closeness_centrality() missing 1 required positional argument: 'S'
#
# group_degree_centrality: Not added
# group_degree_centrality() missing 1 required positional argument: 'S'
#
# group_in_degree_centrality: Not added
# group_in_degree_centrality() missing 1 required positional argument: 'S'
#
# group_out_degree_centrality: Not added
# group_out_degree_centrality() missing 1 required positional argument: 'S'
#
# harmonic_centrality: Added
# has_bridges: Not added
# has_eulerian_path: Not added
# has_path: Not added
# has_path() missing 2 required positional arguments: 'source' and 'target'
#
# hits: Not added
# float division by zero
#
# hits_numpy: Not added
# hits_scipy: Not added
# (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 100 iterations')
#
# hub_matrix: Not added
# contracted_nodes: Not added
# contracted_nodes() missing 2 required positional arguments: 'u' and 'v'
#
# immediate_dominators: Not added
# immediate_dominators() missing 1 required positional argument: 'start'
#
# in_degree_centrality: Not added
# not implemented for undirected type
#
# incremental_closeness_centrality: Not added
# incremental_closeness_centrality() missing 1 required positional argument: 'edge'
#
# current_flow_closeness_centrality: Not added
# Graph not connected.
#
# intersection: Not added
# intersection() missing 1 required positional argument: 'H'
#
# intersection_all: Not added
# 'int' object has no attribute 'add_nodes_from'
#
# intersection_array: Not added
# Graph is not distance regular.
#
# is_aperiodic: Not added
# is_aperiodic not defined for undirected graphs
#
# is_arborescence: Not added
# not implemented for undirected type
#
# is_at_free
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/link_analysis/hits_alg.py:288: RuntimeWarning: invalid value encountered in true_divide
#   x = x / x.max()
# : Not added
# is_attracting_component: Not added
# not implemented for undirected type
#
# is_biconnected: Not added
# is_bipartite: Not added
# is_branching: Not added
# not implemented for undirected type
#
# is_chordal: Not added
# is_connected: Not added
# is_digraphical: Not added
# is_digraphical() missing 1 required positional argument: 'out_sequence'
#
# is_directed_acyclic_graph: Not added
# is_distance_regular: Not added
# is_dominating_set: Not added
# is_dominating_set() missing 1 required positional argument: 'nbunch'
#
# is_edge_cover: Not added
# is_edge_cover() missing 1 required positional argument: 'cover'
#
# is_eulerian: Not added
# is_forest: Not added
# is_graphical: Not added
# is_isolate: Not added
# is_isolate() missing 1 required positional argument: 'n'
#
# is_isomorphic: Not added
# is_isomorphic() missing 1 required positional argument: 'G2'
#
# is_k_edge_connected: Not added
# is_k_edge_connected() missing 1 required positional argument: 'k'
#
# is_k_regular: Not added
# is_k_regular() missing 1 required positional argument: 'k'
#
# is_kl_connected: Not added
# is_kl_connected() missing 2 required positional arguments: 'k' and 'l'
#
# is_matching: Not added
# is_matching() missing 1 required positional argument: 'matching'
#
# is_maximal_matching: Not added
# is_maximal_matching() missing 1 required positional argument: 'matching'
#
# is_multigraphical: Not added
# is_perfect_matching: Not added
# is_perfect_matching() missing 1 required positional argument: 'matching'
#
# is_pseudographical: Not added
# is_regular: Not added
# is_semiconnected: Not added
# not implemented for undirected type
#
# is_semieulerian: Not added
# is_simple_path: Not added
# is_simple_path() missing 1 required positional argument: 'nodes'
#
# is_strongly_connected: Not added
# not implemented for undirected type
#
# is_strongly_regular: Not added
# is_tree: Not added
# is_triad: Not added
# is_valid_degree_sequence_erdos_gallai: Not added
# is_valid_degree_sequence_havel_hakimi: Not added
# is_weakly_connected: Not added
# not implemented for undirected type
#
# isolates: Not added
# jaccard_coefficient: Not added
# johnson: Not added
# Graph is not weighted.
#
# join: Not added
# zip argument #1 must support iteration
#
# junction_tree: Not added
# k_components: Not added
# max() arg is an empty sequence
#
# k_core: Not added
# k_corona: Not added
# k_corona() missing 1 required positional argument: 'k'
#
# k_crust: Not added
# k_edge_augmentation: Not added
# k_edge_augmentation() missing 1 required positional argument: 'k'
#
# k_edge_components: Not added
# k_edge_components() missing 1 required positional argument: 'k'
#
# k_edge_subgraphs: Not added
# k_edge_subgraphs() missing 1 required positional argument: 'k'
#
# k_factor: Not added
# k_factor() missing 1 required positional argument: 'k'
#
# average_degree_connectivity: Not added
# k_shell: Not added
# k_truss: Not added
# k_truss() missing 1 required positional argument: 'k'
#
# katz_centrality: Added
# katz_centrality_numpy: Added
# kl_connected_subgraph: Not added
# kl_connected_subgraph() missing 2 required positional arguments: 'k' and 'l'
#
# kosaraju_strongly_connected_components: Not added
# not implemented for undirected type
#
# lattice_reference: Not added
# float division by zero
#
# lexicographic_product: Not added
# lexicographic_product() missing 1 required positional argument: 'H'
#
# lexicographical_topological_sort: Not added
# newman_betweenness_centrality: Added
# local_bridges: Not added
# local_constraint: Not added
# local_constraint() missing 2 required positional arguments: 'u' and 'v'
#
# local_efficiency: Not added
# local_reaching_centrality: Not added
# local_reaching_centrality() missing 1 required positional argument: 'v'
#
# lowest_common_ancestor: Not added
# lowest_common_ancestor() missing 2 required positional arguments: 'node1' and 'node2'
#
# make_clique_bipartite: Not added
# make_max_clique_graph: Not added
# max_flow_min_cost: Not added
# max_flow_min_cost() missing 2 required positional arguments: 's' and 't'
#
# max_weight_clique: Not added
# 'Node 1981834241 does not have the requested weight field.'
#
# max_weight_matching: Not added
# maximal_independent_set: Not added
# maximal_matching: Not added
# maximum_branching: Not added
# maximum_flow: Not added
# maximum_flow() missing 2 required positional arguments: '_s' and '_t'
#
# maximum_flow_value: Not added
# maximum_flow_value() missing 2 required positional arguments: '_s' and '_t'
#
# maximum_spanning_arborescence: Not added
# not implemented for undirected type
#
# maximum_spanning_edges: Not added
# maximum_spanning_tree: Not added
# min_cost_flow: Not added
# not implemented for undirected type
#
# min_cost_flow_cost: Not added
# not implemented for undirected type
#
# min_edge_cover: Not added
# Graph has a node with no edge incident on it, so no edge cover exists.
#
# minimum_branching: Not added
# minimum_cut: Not added
# minimum_cut() missing 2 required positional arguments: '_s' and '_t'
#
# minimum_cut_value: Not added
# minimum_cut_value() missing 2 required positional arguments: '_s' and '_t'
#
# minimum_cycle_basis: Not added
# minimum_edge_cut: Not added
# Input graph is not connected
#
# minimum_node_cut: Not added
# Input graph is not connected
#
# minimum_spanning_arborescence: Not added
# not implemented for undirected type
#
# minimum_spanning_edges: Not added
# minimum_spanning_tree: Not added
# mixing_dict: Not added
# cannot unpack non-iterable int object
#
# mixing_expansion: Not added
# mixing_expansion() missing 1 required positional argument: 'S'
#
# moral_graph: Not added
# not implemented for undirected type
#
# multi_source_dijkstra: Not added
# multi_source_dijkstra() missing 1 required positional argument: 'sources'
#
# multi_source_dijkstra_path: Not added
# multi_source_dijkstra_path() missing 1 required positional argument: 'sources'
#
# multi_source_dijkstra_path_length: Not added
# multi_source_dijkstra_path_length() missing 1 required positional argument: 'sources'
#
# negative_edge_cycle: Not added
# Frozen graph can't be modified
#
# network_simplex: Not added
# not implemented for undirected type
#
# node_attribute_xy: Not added
# node_attribute_xy() missing 1 required positional argument: 'attribute'
#
# node_boundary: Not added
# node_boundary() missing 1 required positional argument: 'nbunch1'
#
# node_clique_number: Added
# node_connected_component: Not added
# node_connected_component() missing 1 required positional argument: 'n'
#
# node_connectivity: Not added
# node_degree_xy: Not added
# node_disjoint_paths: Not added
# node_disjoint_paths() missing 2 required positional arguments: 's' and 't'
#
# node_expansion: Not added
# node_expansion() missing 1 required positional argument: 'S'
#
# non_randomness: Not added
# Non connected graph.
#
# normalized_cut_size: Not added
# normalized_cut_size() missing 1 required positional argument: 'S'
#
# not_implemented_for: Not added
# number_attracting_components: Not added
# not implemented for undirected type
#
# number_connected_components: Not added
# number_of_cliques: Added
# number_of_isolates: Not added
# number_strongly_connected_components: Not added
# not implemented for undirected type
#
# number_weakly_connected_components: Not added
# not implemented for undirected type
#
# numeric_assortativity_coefficient: Not added
# numeric_assortativity_coefficient() missing 1 required positional argument: 'attribute'
#
# numeric_mixing_matrix: Not added
# numeric_mixing_matrix() missing 1 required positional argument: 'attribute'
#
# omega: Not added
# float division by zero
#
# onion_layers: Added
# optimal_edit_paths: Not added
# optimal_edit_paths() missing 1 required positional argument: 'G2'
#
# optimize_edit_paths: Not added
# optimize_edit_paths() missing 1 required positional argument: 'G2'
#
# optimize_graph_edit_distance: Not added
# optimize_graph_edit_distance() missing 1 required positional argument: 'G2'
#
# out_degree_centrality: Not added
# not implemented for undirected type
#
# overall_reciprocity: Not added
# Not defined for empty graphs
#
# pagerank: Added
# pagerank_numpy: Added
# pagerank_scipy: Added
# percolation_centrality: Added
# periphery: Not added
# Found infinite path length because the graph is not connected
#
# power: Not added
# power() missing 1 required positional argument: 'k'
#
# predecessor: Not added
# predecessor() missing 1 required positional argument: 'source'
#
# preferential_attachment: Not added
# project: Not added
# project() missing 1 required positional argument: 'nodes'
#
# projected_graph: Not added
# projected_graph() missing 1 required positional argument: 'nodes'
#
# quotient_graph: Not added
# quotient_graph() missing 1 required positional argument: 'partition'
#
# ra_index_soundarajan_hopcroft: Not added
# radius: Not added
# Found infinite path length because the graph is not connected
#
# random_reference: Not added
# float division by zero
#
# random_triad: Not added
# not implemented for undirected type
#
# reciprocity: Not added
# Not defined for empty graphs
#
# reconstruct_path: Not added
# reconstruct_path() missing 2 required positional arguments: 'target' and 'predecessors'
#
# recursive_simple_cycles: Not added
# not implemented for undirected type
#
# resistance_distance: Not added
# resistance_distance() missing 2 required positional arguments: 'nodeA' and 'nodeB'
#
# resource_allocation_index: Not added
# reverse: Not added
# Cannot reverse an undirected graph.
#
# rich_club_coefficient: Not added
# pop from empty list
#
# rooted_product: Not added
# rooted_product() missing 2 required positional arguments: 'H' and 'root'
#
# s_metric: Not added
# Normalization not implemented
#
# second_order_centrality: Not added
# Non connected graph.
#
# shortest_path: Not added
# shortest_path_length: Not added
# shortest_simple_paths: Not added
# shortest_simple_paths() missing 2 required positional arguments: 'source' and 'target'
#
# sigma: Not added
# float division by zero
#
# simple_cycles: Not added
# not implemented for undirected type
#
# simrank_similarity: Not added
# simrank_similarity_numpy: Not added
# single_source_bellman_ford: Not added
# single_source_bellman_ford() missing 1 required positional argument: 'source'
#
# single_source_bellman_ford_path: Not added
# single_source_bellman_ford_path() missing 1 required positional argument: 'source'
#
# single_source_bellman_ford_path_length: Not added
# single_source_bellman_ford_path_length() missing 1 required positional argument: 'source'
#
# single_source_dijkstra: Not added
# single_source_dijkstra() missing 1 required positional argument: 'source'
#
# single_source_dijkstra_path: Not added
# single_source_dijkstra_path() missing 1 required positional argument: 'source'
#
# single_source_dijkstra_path_length: Not added
# single_source_dijkstra_path_length() missing 1 required positional argument: 'source'
#
# single_source_shortest_path: Not added
# single_source_shortest_path() missing 1 required positional argument: 'source'
#
# single_source_shortest_path_length: Not added
# single_source_shortest_path_length() missing 1 required positional argument: 'source'
#
# single_target_shortest_path: Not added
# single_target_shortest_path() missing 1 required positional argument: 'target'
#
# single_target_shortest_path_length: Not added
# single_target_shortest_path_length() missing 1 required positional argument: 'target'
#
# spanner: Not added
# spanner() missing 1 required positional argument: 'stretch'
#
# square_clustering: Added
# stoer_wagner: Not added
# graph is not connected.
#
# strong_product: Not added
# strong_product() missing 1 required positional argument: 'H'
#
# strongly_connected_components: Not added
# not implemented for undirected type
#
# strongly_connected_components_recursive: Not added
# not implemented for undirected type
#
# subgraph_centrality: Added
# subgraph_centrality_exp: Added
# symmetric_difference: Not added
# symmetric_difference() missing 1 required positional argument: 'H'
#
# tensor_product: Not added
# tensor_product() missing 1 required positional argument: 'H'
#
# to_nested_tuple: Not added
# to_nested_tuple() missing 1 required positional argument: 'root'
#
# to_prufer_sequence: Not added
# provided graph is not a tree
#
# topological_sort: Not added
# transitive_closure: Not added
# not implemented for undirected type
#
# transitive_closure_dag: Not added
# not implemented for undirected type
#
# transitive_reduction: Not added
# not implemented for undirected type
#
# transitivity: Not added
# tree_all_pairs_lowest_common_ancestor: Not added
# not implemented for undirected type
#
# triad_type: Not added
# not implemented for undirected type
#
# triadic_census: Not added
# not implemented for undirected type
#
# triads_by_type: Not added
# not implemented for undirected type
#
# triangles: Added
# trophic_differences: Not added
# not implemented for undirected type
#
# trophic_incoherence_parameter: Not added
# not implemented for undirected type
#
# trophic_levels: Not added
# not implemented for undirected type
#
# union: Not added
# union() missing 1 required positional argument: 'H'
#
# union_all: Not added
# 'int' object has no attribute 'is_multigraph'
#
# volume: Not added
# volume() missing 1 required positional argument: 'S'
#
# voronoi_cells: Not added
# voronoi_cells() missing 1 required positional argument: 'center_nodes'
#
# voterank: Not added
# weakly_connected_components: Not added
# not implemented for undirected type
#
# weisfeiler_lehman_graph_hash: Not added
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/similarity.py:1427: RuntimeWarning: invalid value encountered in true_divide
#   adjacency_matrix /= adjacency_matrix.sum(axis=0)
# wiener_index: Not added
# within_inter_cluster: Not added
#
# time: 11.4 s (started: 2021-02-27 10:37:20 +00:00)

# %%
len(benchmark)
# Out:
# 29
# time: 4.14 ms (started: 2021-02-27 10:37:32 +00:00)

# %%
quick_methods = sorted(((method, time_taken) for method, time_taken in benchmark.items()), key=lambda x: x[1])
quick_methods
# Out:
# [(<function networkx.algorithms.centrality.degree_alg.degree_centrality>,
#   0.0018117427825927734),
#  (<function networkx.algorithms.structuralholes.constraint>,
#   0.0019478797912597656),
#  (<function networkx.algorithms.structuralholes.effective_size>,
#   0.0021333694458007812),
#  (<function networkx.algorithms.cluster.clustering>, 0.002807140350341797),
#  (<function networkx.algorithms.centrality.eigenvector.eigenvector_centrality>,
#   0.0032052993774414062),
#  (<function networkx.algorithms.core.core_number>, 0.0034215450286865234),
#  (<function networkx.algorithms.link_analysis.pagerank_alg.pagerank>,
#   0.003622770309448242),
#  (<function networkx.algorithms.cluster.triangles>, 0.003744363784790039),
#  (<function networkx.algorithms.coloring.greedy_coloring.greedy_color>,
#   0.0039539337158203125),
#  (<function networkx.algorithms.centrality.load.newman_betweenness_centrality>,
#   0.00399327278137207),
#  (<function networkx.algorithms.centrality.katz.katz_centrality>,
#   0.003996610641479492),
#  (<function networkx.algorithms.clique.node_clique_number>,
#   0.0040395259857177734),
#  (<function networkx.algorithms.core.onion_layers>, 0.0052394866943359375),
#  (<function networkx.algorithms.assortativity.neighbor_degree.average_neighbor_degree>,
#   0.006608486175537109),
#  (<function networkx.algorithms.centrality.katz.katz_centrality_numpy>,
#   0.007406949996948242),
#  (<function networkx.algorithms.cluster.square_clustering>,
#   0.007506847381591797),
#  (<function networkx.algorithms.centrality.closeness.closeness_centrality>,
#   0.008039236068725586),
#  (<function networkx.algorithms.centrality.betweenness.betweenness_centrality>,
#   0.008209943771362305),
#  (<function networkx.algorithms.link_analysis.pagerank_alg.pagerank_scipy>,
#   0.008358955383300781),
#  (<function networkx.algorithms.centrality.betweenness_subset.betweenness_centrality_source>,
#   0.008727550506591797),
#  (<function networkx.algorithms.centrality.harmonic.harmonic_centrality>,
#   0.008931398391723633),
#  (<function networkx.algorithms.clique.number_of_cliques>,
#   0.010635614395141602),
#  (<function networkx.algorithms.centrality.subgraph_alg.subgraph_centrality_exp>,
#   0.010963678359985352),
#  (<function networkx.algorithms.centrality.subgraph_alg.subgraph_centrality>,
#   0.01107168197631836),
#  (<function networkx.algorithms.centrality.eigenvector.eigenvector_centrality_numpy>,
#   0.013440370559692383),
#  (<function networkx.algorithms.centrality.percolation.percolation_centrality>,
#   0.0161895751953125),
#  (<function networkx.algorithms.link_analysis.pagerank_alg.pagerank_numpy>,
#   0.023642301559448242),
#  (<function networkx.algorithms.vitality.closeness_vitality>,
#   0.034479379653930664),
#  (<function networkx.algorithms.centrality.subgraph_alg.communicability_betweenness_centrality>,
#   0.18839144706726074)]
# time: 8.13 ms (started: 2021-02-27 10:37:32 +00:00)

# %%
# [('effective_size', 0.00012493133544921875),
#  ('degree_centrality', 0.00014328956604003906),
#  ('constraint', 0.00015497207641601562),
#  ('triangles', 0.00016260147094726562),
#  ('number_of_cliques', 0.00018095970153808594),
#  ('greedy_color', 0.0001876354217529297),
#  ('newman_betweenness_centrality', 0.00018858909606933594),
#  ('core_number', 0.0002040863037109375),
#  ('harmonic_centrality', 0.0002067089080810547),
#  ('clustering', 0.0002186298370361328),
#  ('square_clustering', 0.00023293495178222656),
#  ('eigenvector_centrality', 0.0002429485321044922),
#  ('katz_centrality', 0.00025582313537597656),
#  ('betweenness_centrality_source', 0.000308990478515625),
#  ('closeness_centrality', 0.00031447410583496094),
#  ('percolation_centrality', 0.00032329559326171875),
#  ('average_neighbor_degree', 0.0003249645233154297),
#  ('subgraph_centrality', 0.00032520294189453125),
#  ('betweenness_centrality', 0.0003304481506347656),
#  ('onion_layers', 0.0003974437713623047),
#  ('node_clique_number', 0.0004062652587890625),
#  ('pagerank', 0.0005104541778564453),
#  ('pagerank_numpy', 0.0007638931274414062),
#  ('closeness_vitality', 0.0008549690246582031),
#  ('subgraph_centrality_exp', 0.0009100437164306641),
#  ('katz_centrality_numpy', 0.0010249614715576172),
#  ('pagerank_scipy', 0.001619100570678711),
#  ('eigenvector_centrality_numpy', 0.0018410682678222656),
#  ('communicability_betweenness_centrality', 0.0054891109466552734)]
# Out:
# time: 5.99 ms (started: 2021-02-27 10:37:32 +00:00)

# %%
N = 1000
random_nodes = G.subgraph(sample(list(G.nodes()), N))
# Out:
# time: 64.8 ms (started: 2021-02-27 10:37:32 +00:00)

# %%
benchmark_fast = {}
# Out:
# time: 2.45 ms (started: 2021-02-27 10:37:32 +00:00)

# %%
filtered_methods = ["percolation_centrality", "communicability_betweenness_centrality"]
methods_fast = [x[0] for x in quick_methods if _produce_name(x[0]) not in filtered_methods]

for method in tqdm(methods_fast):
    method_repr = _produce_name(method)
    print(method_repr, end="")
    start = time()
    try:
        res = method(random_nodes)
        if type(res) == dict and list(res.keys())[0] in random_nodes.nodes() and isinstance(list(res.values())[0], numbers.Number):
            benchmark_fast[method] = time()-start
            print(": Added")
        else:
            print(": Not added")
    except Exception as e:
        print(": Not added")
        print(str(e) + "\n")
        pass
# Out:
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# degree_centrality: Added
# constraint: Added
# effective_size: Added
# clustering: Added
# eigenvector_centrality: Added
# core_number: Added
# pagerank: Added
# triangles: Added
# greedy_color: Added
# newman_betweenness_centrality: Added
# katz_centrality: Added
# node_clique_number: Added
# onion_layers: Added
# average_neighbor_degree: Added
# katz_centrality_numpy: Added
# square_clustering: Added
# closeness_centrality: Added
# betweenness_centrality: Added
# pagerank_scipy: Added
# betweenness_centrality_source: Added
# harmonic_centrality: Added
# number_of_cliques: Added
# subgraph_centrality_exp: Added
# subgraph_centrality: Added
# eigenvector_centrality_numpy: Added
# pagerank_numpy: Added
# closeness_vitality: Added
#
# time: 12.8 s (started: 2021-02-27 10:37:32 +00:00)

# %%
fast_methods = sorted(((method, time_taken) for method, time_taken in benchmark_fast.items()), key=lambda x: x[1])
str_fast_methods = [(_produce_name(method), time_taken) for method, time_taken in fast_methods]
str_quick_methods = [(_produce_name(method), time_taken) for method, time_taken in quick_methods]
str_fast_methods
# Out:
# [('degree_centrality', 0.026424169540405273),
#  ('greedy_color', 0.03774547576904297),
#  ('clustering', 0.044959068298339844),
#  ('pagerank_scipy', 0.04802584648132324),
#  ('triangles', 0.04928445816040039),
#  ('core_number', 0.04981493949890137),
#  ('average_neighbor_degree', 0.05359339714050293),
#  ('newman_betweenness_centrality', 0.05432844161987305),
#  ('onion_layers', 0.06090807914733887),
#  ('eigenvector_centrality_numpy', 0.06296896934509277),
#  ('node_clique_number', 0.0753183364868164),
#  ('pagerank', 0.0848534107208252),
#  ('number_of_cliques', 0.09130644798278809),
#  ('katz_centrality_numpy', 0.09653091430664062),
#  ('eigenvector_centrality', 0.15868782997131348),
#  ('square_clustering', 0.18868017196655273),
#  ('katz_centrality', 0.2028517723083496),
#  ('constraint', 0.25261902809143066),
#  ('subgraph_centrality', 0.2731895446777344),
#  ('harmonic_centrality', 0.3767530918121338),
#  ('effective_size', 0.6420180797576904),
#  ('closeness_centrality', 0.7068426609039307),
#  ('subgraph_centrality_exp', 0.795905590057373),
#  ('pagerank_numpy', 1.2356865406036377),
#  ('betweenness_centrality', 1.8945062160491943),
#  ('betweenness_centrality_source', 1.9140112400054932),
#  ('closeness_vitality', 3.228886842727661)]
# time: 8.85 ms (started: 2021-02-27 10:37:45 +00:00)

# %%
quick_methods_ = [x[0] for x in quick_methods]
index_changed = sorted(
    [
        (
            method, 
            tau/(10*quick_methods[quick_methods_.index(method)][1]),
            abs(i - quick_methods_.index(method))
        ) 
        for i, (method, tau) in enumerate(fast_methods)
        if method in quick_methods_
    ], 
    key=lambda x: (x[1], x[2])
)
[(_produce_name(x), val1, val2) for x, val1, val2 in index_changed]
# Out:
# [('eigenvector_centrality_numpy', 0.4685061997764887, 15),
#  ('pagerank_scipy', 0.5745436394751854, 15),
#  ('average_neighbor_degree', 0.8109784255718305, 7),
#  ('number_of_cliques', 0.8584971642493667, 9),
#  ('greedy_color', 0.954630969609262, 7),
#  ('onion_layers', 1.1624817983254458, 4),
#  ('katz_centrality_numpy', 1.3032478192294075, 1),
#  ('triangles', 1.316230499840815, 3),
#  ('newman_betweenness_centrality', 1.3604991342766732, 2),
#  ('core_number', 1.455919448122082, 0),
#  ('degree_centrality', 1.4584945387550994, 0),
#  ('clustering', 1.6015967385765246, 1),
#  ('node_clique_number', 1.864534025851384, 1),
#  ('pagerank', 2.3422244159262915, 5),
#  ('subgraph_centrality', 2.4674619923338645, 5),
#  ('square_clustering', 2.51344089436575, 0),
#  ('harmonic_centrality', 4.218299030992232, 1),
#  ('eigenvector_centrality', 4.9507958940791434, 10),
#  ('katz_centrality', 5.075595060550021, 6),
#  ('pagerank_numpy', 5.226591571453062, 3),
#  ('subgraph_centrality_exp', 7.259475916059585, 0),
#  ('closeness_centrality', 8.792410806963433, 5),
#  ('closeness_vitality', 9.364689490170589, 1),
#  ('constraint', 12.968922888616891, 16),
#  ('betweenness_centrality_source', 21.930680762716495, 6),
#  ('betweenness_centrality', 23.07575141571076, 7),
#  ('effective_size', 30.094088064371928, 18)]
# time: 16.6 ms (started: 2021-02-27 10:37:45 +00:00)

# %%
forbidden_methods = [
    "dfs_predecessors", 
    "harmonic_centrality", 
    "pagerank", 
    "pagerank_numpy",  
    "katz_centrality", 
    "subgraph_centrality", 
    "subgraph_centrality_exp", 
    "effective_size", 
    "closeness_vitality", 
    "betweenness_centrality_source", 
    "betweenness_centrality", 
    "eigenvector_centrality", 
    "closeness_centrality",
    "number_of_cliques",
    "constraint",
    "square_clustering",
    "katz_centrality_numpy",
    "node_clique_number"
]
# benchmark square clustering, constraint
final_methods = [x[0] for x in index_changed if _produce_name(x[0]) not in forbidden_methods]
final_methods
# Out:
# [<function networkx.algorithms.centrality.eigenvector.eigenvector_centrality_numpy>,
#  <function networkx.algorithms.link_analysis.pagerank_alg.pagerank_scipy>,
#  <function networkx.algorithms.assortativity.neighbor_degree.average_neighbor_degree>,
#  <function networkx.algorithms.coloring.greedy_coloring.greedy_color>,
#  <function networkx.algorithms.core.onion_layers>,
#  <function networkx.algorithms.cluster.triangles>,
#  <function networkx.algorithms.centrality.load.newman_betweenness_centrality>,
#  <function networkx.algorithms.core.core_number>,
#  <function networkx.algorithms.centrality.degree_alg.degree_centrality>,
#  <function networkx.algorithms.cluster.clustering>,
#  <function networkx.algorithms.clique.node_clique_number>]
# time: 13.9 ms (started: 2021-02-27 10:37:45 +00:00)

# %%
graph_features = []

M = 2000
random_nodes = G.subgraph(sample(list(G.nodes()), M))

for m in tqdm(final_methods):
    t0 = time()
    print(f"Method {_produce_name(m)}", end="")
    graph_features.append(m(random_nodes))
    print(f": Took {(time() - t0)/60:.3f} minutes.")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# Method eigenvector_centrality_numpy: Took 0.001 minutes.
# Method pagerank_scipy: Took 0.002 minutes.
# Method average_neighbor_degree: Took 0.003 minutes.
# Method greedy_color: Took 0.001 minutes.
# Method onion_layers: Took 0.002 minutes.
# Method triangles: Took 0.002 minutes.
# Method newman_betweenness_centrality: Took 0.006 minutes.
# Method core_number: Took 0.002 minutes.
# Method degree_centrality: Took 0.001 minutes.
# Method clustering: Took 0.002 minutes.
# Method node_clique_number: Took 0.006 minutes.
#
# time: 1.84 s (started: 2021-02-27 10:50:05 +00:00)

# %% [markdown]
# Method eigenvector_centrality_numpy: Took 0.032 minutes.
# Method pagerank_scipy: Took 0.022 minutes.
# Method average_neighbor_degree: Took 0.180 minutes.
# Method greedy_color: Took 0.013 minutes.
# Method onion_layers: Took 0.027 minutes.
# Method triangles: Took 0.185 minutes.
# Method newman_betweenness_centrality: Took 1.664 minutes.
# Method core_number: Took 0.014 minutes.
# Method degree_centrality: Took 0.006 minutes.
# Method clustering: Took 0.182 minutes.
# Method node_clique_number: Took 2.123 minutes

# %%
# Method pagerank_scipy: Took 0.017 minutes. # x10
# Method square_clustering: Took 5.440 minutes. # almost x1000
# Method eigenvector_centrality_numpy: Took 0.017 minutes. # x10
# Method greedy_color: Took 0.011 minutes. # x10
# Method clustering: Took 0.074 minutes. # x30
# Method node_clique_number: Took 0.947 minutes. # almost x100
# Method number_of_cliques: Took 0.839 minutes. # almost x100
# Method harmonic_centrality: Took 5.198 minutes.# almost x300

# %%
import numpy as np

np.save("graph_features.npy", graph_features)

# %%
# computes structural features for each node
core_number = nx.core_number(G)
onion_number = nx.onion_layers(G)
avg_neighbor_degree = nx.average_neighbor_degree(G)
degree_centrality = nx.degree_centrality(G)
clustering = nx.clustering(G)
print("Features computed")
# Out:
# Features computed
# time: 3min 55s (started: 2021-02-08 10:17:17 +00:00)

# %%
# create the training matrix. each node is represented as a vector of 3 features:
# (1) its degree, (2) its core number and (3) the average degree of its neighbors
X_train_graph = np.zeros((n_train, 7))
y_train_graph = np.zeros(n_train)
for i, row in df_train.iterrows():
    node = row['authorID']
    X_train_graph[i, 0] = G.degree(node)
    X_train_graph[i, 1] = core_number[node]
    X_train_graph[i, 2] = avg_neighbor_degree[node]
    X_train_graph[i, 3] = onion_number[node]
    X_train_graph[i, 4] = degree_centrality[node]
    X_train_graph[i, 5] = clustering[node]
    X_train_graph[i, 6] = row['authorID']
    y_train_graph[i] = row['h_index']
# Out:
# time: 1.96 s (started: 2021-02-08 10:21:13 +00:00)

# %%
X_test_graph = np.zeros((n_test, 7))
for i, row in df_test.iterrows():
    node = row['authorID']
    X_test_graph[i, 0] = G.degree(node)
    X_test_graph[i, 1] = core_number[node]
    X_test_graph[i, 2] = avg_neighbor_degree[node]
    X_test_graph[i, 3] = onion_number[node]
    X_test_graph[i, 4] = degree_centrality[node]
    X_test_graph[i, 5] = clustering[node]
    X_test_graph[i, 6] = row['authorID']
# Out:
# time: 17 s (started: 2021-02-08 10:21:15 +00:00)

# %%
print(X_train_graph.shape)
print(y_train_graph.shape)
print(X_test_graph.shape)
# Out:
# (23124, 7)
# (23124,)
# (208115, 7)
# time: 3.04 ms (started: 2021-02-08 10:21:32 +00:00)

# %%
## Merge text features and graph
columns=["degree", "core_number", "avg_neighbors", "onion_number", "degree_centrality", "clustering", "authorID"]

X_train_graph_df = pd.DataFrame(
    X_train_graph, 
    columns=columns
)
X_test_graph_df = pd.DataFrame(
    X_test_graph,
    columns=columns
)
# Out:
# time: 9.31 ms (started: 2021-02-08 10:21:32 +00:00)

# %%
X_train = X_train_graph_df.merge(df_train, on="authorID")
X_test = X_test_graph_df.merge(df_test, on="authorID")
# Out:
# time: 842 ms (started: 2021-02-08 10:21:32 +00:00)

# %%
X_train = X_train.merge(author_num_papers_train, on="authorID")
X_test = X_test.merge(author_num_papers_test, on="authorID")
# Out:
# time: 521 ms (started: 2021-02-08 10:21:33 +00:00)

# %%
X_test
# Out:
#         degree  core_number  ...       256  paper_per_author
# 0         16.0          5.0  ... -0.584914                10
# 1          2.0          2.0  ... -0.762944                10
# 2        107.0         13.0  ... -0.418734                10
# 3          3.0          3.0  ... -0.686180                10
# 4          2.0          2.0  ... -0.836433                 1
# ...        ...          ...  ...       ...               ...
# 208110     2.0          2.0  ... -0.162939                 1
# 208111     4.0          4.0  ... -3.153230                 1
# 208112    10.0         10.0  ...  0.000000                 1
# 208113     1.0          1.0  ... -0.125780                 8
# 208114     3.0          3.0  ... -2.013633                 1
#
# [208115 rows x 265 columns]
# time: 501 ms (started: 2021-02-08 10:21:34 +00:00)

# %%
# Removing h_index and author_id
y_train = X_train["h_index"]
X_train.drop(columns=["authorID", "h_index"], inplace=True)
print(X_train.head())

X_test.drop(columns=["authorID", "h_index_pred"], inplace=True)
print(X_test.head())
# Out:
#    degree  core_number  avg_neighbors  ...       255       256  paper_per_author
# 0     3.0          3.0      13.333333  ...  1.284111 -0.491038                 4
# 1     5.0          5.0      23.200000  ...  0.506366 -1.664988                10
# 2     5.0          5.0       6.000000  ... -0.286176 -0.743096                 1
# 3     3.0          3.0      40.333333  ... -0.192451  1.583816                 1
# 4     4.0          2.0       7.250000  ... -1.457717  0.290012                10
#
# [5 rows x 263 columns]
#    degree  core_number  avg_neighbors  ...       255       256  paper_per_author
# 0    16.0          5.0       6.375000  ... -0.851161 -0.584914                10
# 1     2.0          2.0      40.000000  ...  0.029991 -0.762944                10
# 2   107.0         13.0      19.906542  ...  1.061965 -0.418734                10
# 3     3.0          3.0      10.666667  ... -0.190372 -0.686180                10
# 4     2.0          2.0       2.500000  ... -0.413302 -0.836433                 1
#
# [5 rows x 263 columns]
# time: 794 ms (started: 2021-02-08 10:21:34 +00:00)

# %%
# scale for 0 mean and 1 std per col
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(
    X_train_scaled, y_train, test_size=0.2, random_state=42
)
# Out:
# time: 861 ms (started: 2021-02-08 10:21:35 +00:00)

# %%
# train a regression model and make predictions
model = xgb.XGBRegressor(n_jobs=-1)
model.fit(X_train_final, y_train_final)
# Out:
# [10:21:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)
# time: 32.1 s (started: 2021-02-08 10:21:36 +00:00)

# %%
y_pred = model.predict(X_test_final)
print(f"Loss: {mean_absolute_error(y_test_final, y_pred)}")
# Out:
# Loss: 4.655028820037842
# time: 45.5 ms (started: 2021-02-08 10:22:08 +00:00)

# %%
# Save to file
y_pred_save = model.predict(X_test_scaled)
df_test['h_index_pred'].update(pd.Series(np.round_(y_pred_save, decimals=3)))
df_test.loc[:, ["authorID", "h_index_pred"]].to_csv(
    'predictions.csv', index=False
)
# Out:
# time: 2.17 s (started: 2021-02-08 10:22:08 +00:00)

# %%
df_test.loc[:, ["authorID", "h_index_pred"]]
# Out:
#           authorID  h_index_pred
# 0          1036332     20.136999
# 1          1101850     10.493000
# 2          1336878     32.626999
# 3          1515524      8.954000
# 4          1606427      1.015000
# ...            ...           ...
# 208110  2908387141      4.431000
# 208111  2908425732      1.765000
# 208112  2908436250      1.621000
# 208113  2908499439      5.597000
# 208114  2908506980      0.632000
#
# [208115 rows x 2 columns]
# time: 19.5 ms (started: 2021-02-07 11:03:47 +00:00)

# %%
## Hyper parameter search
train_dmatrix = xgb.DMatrix(data=X_train_final, label=y_train_final)
# Out:
# time: 39.3 ms (started: 2021-02-07 11:03:47 +00:00)

# %% [markdown]
# ## Early stopping for num of boosting rounds

# %%
# Creata the parameter dictionary for each tree: params
params = {
    "objective":"reg:squarederror", 
    "max_depth": 5,
    "n_estimators": 200
}

# Perform cross-validation with early-stopping: cv_results
cv_results = xgb.cv(
    dtrain=train_dmatrix, 
    nfold=4, 
    params=params, 
    metrics="mae", 
    early_stopping_rounds=10, 
    num_boost_round=100,
    seed=123
)

cv_results
# Out:
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0         6.512381       0.033530       6.530529      0.122788
# 1         5.230396       0.030879       5.292411      0.131111
# 2         4.681756       0.027850       4.796288      0.139419
# 3         4.440768       0.027814       4.615366      0.142417
# 4         4.314823       0.029789       4.557977      0.140311
# 5         4.239606       0.027406       4.545356      0.127317
# 6         4.182877       0.026721       4.539812      0.114327
# 7         4.144245       0.024540       4.537821      0.108271
# 8         4.104380       0.019467       4.541241      0.105299
# 9         4.059746       0.018686       4.538721      0.103680
# 10        4.011544       0.018462       4.540724      0.098882
# 11        3.969213       0.015545       4.539878      0.093624
# 12        3.925572       0.016473       4.536955      0.095537
# 13        3.888956       0.016689       4.543103      0.088194
# 14        3.857279       0.022323       4.539264      0.081766
# 15        3.815661       0.019085       4.526284      0.079085
# 16        3.781229       0.020461       4.531713      0.083478
# 17        3.747499       0.024232       4.531349      0.082407
# 18        3.717136       0.020853       4.520039      0.082373
# 19        3.684262       0.022220       4.513883      0.077170
# 20        3.651714       0.026761       4.508451      0.074796
# 21        3.622872       0.027443       4.499397      0.077157
# time: 55.8 s (started: 2021-02-07 11:07:13 +00:00)

# %% [markdown]
# ## Tunig eta (learning rate)

# %%
# Create list of eta values and empty list to store final round rmse per xgboost model
eta_vals = [0.001, 0.01, 0.1]
best_rmse = []

# Systematicallyvary the eta
for curr_val in eta_vals:
    params['eta'] = curr_val
    
    # Perform cross-validation: cv_results
    cv_results = xgb.cv(dtrain=train_dmatrix, params=params, nfold=4,
                        early_stopping_rounds=5, num_boost_round=10, metrics='mae', seed=123, 
                       as_pandas=True)
    
    # Append the final round rmse to best_rmse
    best_rmse.append(cv_results['test-mae-mean'].tail().values[-1])
    
# Print the result DataFrame
print(pd.DataFrame(list(zip(eta_vals, best_rmse)), columns=['eta', 'best_mae']))
# Out:
#      eta  best_mae
# 0  0.001  8.974660
# 1  0.010  8.204939
# 2  0.100  4.830492
# time: 36.8 s (started: 2021-02-06 20:14:08 +00:00)

# %% [markdown]
# ## Tunig tree depth

# %%
# Create the parameter dictionary
params = {"objective":"reg:squarederror"}

# Create list of max_depth values
max_depths = [2, 5, 10, 20, 50, 100, 500, 1000]
best_rmse = []

for curr_val in max_depths:
    params['max_depth'] = curr_val
    
    # Perform cross-validation
    cv_results = xgb.cv(dtrain=train_dmatrix, params=params, nfold=4, 
                       early_stopping_rounds=10, num_boost_round=50, metrics='mae', seed=123,
                        as_pandas=True)
    
    # Append the final round rmse to best_rmse
    best_rmse.append(cv_results['test-mae-mean'].tail().values[-1])
    
# Print the result DataFrame
print(pd.DataFrame(list(zip(max_depths, best_rmse)), columns=['max_depth', 'best_mae']))
# Out:
#    max_depth  best_mae
# 0          2  5.020174
# 1          5  4.499397
# 2         10  4.505210
# 3         20  4.602783
# 4         50  4.619110
# 5        100  4.619110
# 6        500  4.619110
# 7       1000  4.619110
# time: 12min 55s (started: 2021-02-06 20:14:45 +00:00)

# %% [markdown]
# # Tuning colsample_bytree

# %%
# Create the parameter dictionary
params={"objective":"reg:squarederror", "max_depth":3}

# Create list of hyperparameter values: colsample_bytree_vals
colsample_bytree_vals = [0.1, 0.5, 0.8, 1]
best_rmse = []

# Systematically vary the hyperparameter value 
for curr_val in colsample_bytree_vals:
    params['colsample_bytree'] = curr_val
    
    # Perform cross-validation
    cv_results = xgb.cv(dtrain=train_dmatrix, params=params, nfold=4,
                 num_boost_round=10, early_stopping_rounds=5,
                 metrics="mae", as_pandas=True, seed=123)
    
    # Append the final round rmse to best_rmse
    best_rmse.append(cv_results["test-mae-mean"].tail().values[-1])

# Print the resultant DataFrame
print(pd.DataFrame(list(zip(colsample_bytree_vals, best_rmse)), 
                   columns=["colsample_bytree","best_mae"]))
# Out:
#    colsample_bytree  best_mae
# 0               0.1  5.618477
# 1               0.5  4.950673
# 2               0.8  4.782896
# 3               1.0  4.796019
# time: 29.4 s (started: 2021-02-06 20:27:41 +00:00)

# %%
from sklearn.model_selection import GridSearchCV

# Create the parameter grid: gbm_param_grid
gbm_param_grid = {
    'colsample_bytree': [0.8],
    'n_estimators': [200],
    'max_depth': [5],
    'eta': [0.1, 0.2, 0.5],
    'early_stopping_rounds': [10], 
    'num_boost_round': [10]
}

# Instantiate the regressor: gbm
gbm = xgb.XGBRegressor()

# Perform grid search: grid_mse
grid_mse = GridSearchCV(param_grid=gbm_param_grid, estimator=gbm, 
                        scoring='neg_mean_absolute_error', cv=2, verbose=1, n_jobs=-1)

# Fit grid_mse to the data
grid_mse.fit(X_train_scaled, y_train)

# Print the best parameters and lowest RMSE
print("Best parameters found: ", grid_mse.best_params_)
print("Lowest MAE found: ", np.abs(grid_mse.best_score_))
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  4.4min finished
# [20:45:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Best parameters found:  {'colsample_bytree': 0.8, 'early_stopping_rounds': 10, 'eta': 0.1, 'max_depth': 5, 'n_estimators': 200, 'num_boost_round': 10}
# Lowest MAE found:  4.370246171951294
# time: 6min 9s (started: 2021-02-06 20:41:17 +00:00)

# %% [markdown]
# Best parameters found:  {'colsample_bytree': 0.8, 'early_stopping_rounds': 10, 'eta': 0.1, 'max_depth': 5, 'n_estimators': 100, 'num_boost_round': 10}
#
# 4.37

# %% [markdown]
# ## Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# Create the parameter grid: here it corresponds to a range of values it can take from (distribution sort of)
gbm_param_grid = {
    'n_estimators': range(1, 1000),
    'max_depth': range(2, 12),
    'colsample_bytree': [0.1*i for i in range(1, 10)],
    'eta': [0.001*i for i in range(1, 10)] + [0.01*i for i in range(1, 10)] + [0.1*i for i in range(1, 10)],
}

# Instantiate the regressor: gbm
gbm = xgb.XGBRegressor()

# Perform random search: randomized_mse
randomized_mae = RandomizedSearchCV(param_distributions=gbm_param_grid, estimator=gbm, 
                                    scoring='neg_mean_absolute_error', n_iter=100, cv=2, 
                                   verbose=1, n_jobs=-1)

# Fit randomized_mse to the data
randomized_mae.fit(X_train, y_train)

# Print the best parameters and lowest RMSE
print("Best parameters found: ", randomized_mae.best_params_)
print("Lowest MAE found: ", np.abs(randomized_mae.best_score_))

# %%
# Save to file
model = xgb.XGBRegressor(
    n_estimators= 12, 
    max_depth= 7, 
    eta= 0.06, 
    colsample_bytree=0.8,
)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
df_test['h_index_pred'].update(pd.Series(np.round_(y_pred, decimals=3)))
df_test.loc[:, ["authorID", "h_index_pred"]].to_csv(
    'predictions.csv', index=False
)
